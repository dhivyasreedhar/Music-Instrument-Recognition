# %% [markdown]
# <a href="https://colab.research.google.com/github/dhivyasreedhar/Music-Instrument-Recognition/blob/main/audioplt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/GuitarsAI/BasicsMusicalInstrumClassifi
# !unzip ./BasicsMusicalInstrumClassifi/audio/*.zip -d ./BasicsMusicalInstrumClassifi/audio
path="./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/"
# Out:
# Cloning into 'BasicsMusicalInstrumClassifi'...
# remote: Enumerating objects: 904, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 904 (delta 3), reused 0 (delta 0), pack-reused 895
# Receiving objects: 100% (904/904), 14.10 MiB | 28.43 MiB/s, done.
# Resolving deltas: 100% (163/163), done.
# Archive:  ./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi.zip
#    creating: ./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/
#   inflating: ./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/mfcc_feature_vectors.pl
#  extracting: ./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/max_length.pl
#    creating: ./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/viola/
#   inflating: ./BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/viola/viola_Ds3_05_fortissimo_arco-normal.mp3
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Plot Using Librosa Module
# !pip install librosa

# %%
import librosa
import librosa.display

# %%
y,sr=librosa.load('/content/BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/cello/cello_A2_025_forte_arco-normal.mp3',duration=3)
plt.figure()
plt.subplot(2,1,1)
librosa.display.waveplot(y,sr=sr)
plt.title('Monophonic')
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Text(0.5, 1.0, 'Monophonic')

# %%
y,sr=librosa.load('/content/BasicsMusicalInstrumClassifi/audio/london_phill_dataset_multi/cello/cello_A2_025_forte_arco-normal.mp3',duration=3)
y_harm,y_perc=librosa.effects.hpss(y)
plt.subplot(2,1,2)
librosa.display.waveplot(y_harm,sr=sr,alpha=0.25)
librosa.display.waveplot(y_perc,sr=sr,color='r',alpha=0.5)
plt.title('Harmonic+Percussive')
plt.tight_layout()
plt.savefig('signal.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
# !pip install dtw
# Out:
# ...
#   Created wheel for dtw: filename=dtw-1.4.0-cp37-none-any.whl size=5316 sha256=4202a1330d384af867f2954300f594804b657c5ffbd750a91a6f41b9dfb49ae2
#   Stored in directory: /root/.cache/pip/wheels/8c/8b/7a/947d67b53cd54948890a173527b0470ef56998812fc9d0a803
# Successfully built dtw
# ...

# %%
S,phase=librosa.magphase(librosa.stft(y=y))
librosa.display.specshow(librosa.amplitude_to_db(S,ref=np.max),y_axis='log',x_axis='time')
plt.title('log Power Spectogram')
plt.tight_layout()
plt.savefig('spectogram.png')
